# %%
# %matplotlib inline
import pandas as pd
data = pd.read_csv('player_regular_season_career.csv')

# %%
data.head(100)
# Out:
#         ilkid firstname      lastname leag    gp  minutes    pts  oreb  dreb  \
# 0   ABDELAL01      Alaa     Abdelnaby    N   256     3200   1465   283   563
# 1   ABDULKA01    Kareem  Abdul-jabbar    N  1560    57446  38387  2975  9394
# 2   ABDULMA01     Mahmo    Abdul-rauf    N   586    15633   8553   219   868
# 3   ABDULTA01     Tariq   Abdul-wahad    N   236     4808   1830   275   501
# 4   ABDURSH01   Shareef   Abdur-rahim    N   672    24862  13338  1498  3976
# ..        ...       ...           ...  ...   ...      ...    ...   ...   ...
# 95  ARTHUJO01      John       Arthurs    N    11       86     35     0     0
# 96  ASKEWVI01   Vincent         Askew    N   467     9361   3313   400   776
# 97  ASKINKE01     Keith        Askins    N   486     7983   1852   525   903
# 98  ASMONDO01       Don       Asmonga    N     7       46      5     0     0
# 99   ATHARI01   Richard          Atha    N    43      448    137     0     0
#
# ...

# %%
playerID = data['ilkid'] 
x = data.drop(columns=['ilkid','firstname','lastname','gp','minutes'])
x.head()
# Out:
#   leag    pts  oreb  dreb    reb  asts   stl   blk  turnover    pf    fga  \
# 0    N   1465   283   563    846    85    71    69       247   484   1236
# 1    N  38387  2975  9394  17440  5660  1160  3189      2527  4657  28307
# 2    N   8553   219   868   1087  2079   487    46       963  1107   7943
# 3    N   1830   275   501    776   266   184    82       309   485   1726
# 4    N  13338  1498  3976   5474  1847   718   556      1911  1845  10215
#
#      fgm   fta   ftm   tpa  tpm
# 0    620   321   225     3    0
# 1  15837  9304  6712    18    1
# 2   3514  1161  1051  1339  474
# 3    720   529   372    76   18
# 4   4789  4427  3614   477  146

# %%
PIR = (data["pts"]+data['reb']+data['asts']+data['stl']+data['blk']+data['pf'])-((data['fga']-data['fgm'])+(data['fta']-data['ftm'])+data['turnover']+data['dreb']+0)
print(PIR)
#(Points + Rebounds + Assists + Steals + Blocks + Fouls Drawn) - (Missed Field Goals + Missed Free Throws + Turnovers + Shots Rejected + Fouls Committed)
# Out:
# 0        1498
# 1       43510
# 2        6989
# 3        1650
# 4       11652
#         ...
# 3754       35
# 3755      521
# 3756       11
# 3757      169
# 3758      248
# Length: 3759, dtype: int64

# %%
data['Name'] = data['firstname'].map(str) + ' ' + data['lastname'].map(str)

# %%
data.head(50)
# Out:
#         ilkid firstname      lastname leag    gp  minutes    pts  oreb  dreb  \
# 0   ABDELAL01      Alaa     Abdelnaby    N   256     3200   1465   283   563
# 1   ABDULKA01    Kareem  Abdul-jabbar    N  1560    57446  38387  2975  9394
# 2   ABDULMA01     Mahmo    Abdul-rauf    N   586    15633   8553   219   868
# 3   ABDULTA01     Tariq   Abdul-wahad    N   236     4808   1830   275   501
# 4   ABDURSH01   Shareef   Abdur-rahim    N   672    24862  13338  1498  3976
# 5   ABERNTO01       Tom     Abernethy    N   319     5434   1779   374   637
# 6    ABLEFO01    Forest          Able    N     1        1      0     0     0
# 7   ABRAMJO01      John     Abramovic    N    56        0    533     0     0
# 8   ACKERDO01    Donald      Ackerman    N    28      220     43     0     0
# 9   ACRESMA01      Mark         Acres    N   375     5982   1343   581   944
# 10  ACTONCH01   Charles         Acton    N    23      195     77     0     0
# ...

# %%
data = data.assign(firstname=data['Name'])

# %%
data.head(50)
# Out:
#         ilkid            firstname      lastname leag    gp  minutes    pts  \
# 0   ABDELAL01       Alaa Abdelnaby     Abdelnaby    N   256     3200   1465
# 1   ABDULKA01  Kareem Abdul-jabbar  Abdul-jabbar    N  1560    57446  38387
# 2   ABDULMA01     Mahmo Abdul-rauf    Abdul-rauf    N   586    15633   8553
# 3   ABDULTA01    Tariq Abdul-wahad   Abdul-wahad    N   236     4808   1830
# 4   ABDURSH01  Shareef Abdur-rahim   Abdur-rahim    N   672    24862  13338
# 5   ABERNTO01        Tom Abernethy     Abernethy    N   319     5434   1779
# 6    ABLEFO01          Forest Able          Able    N     1        1      0
# 7   ABRAMJO01       John Abramovic     Abramovic    N    56        0    533
# 8   ACKERDO01      Donald Ackerman      Ackerman    N    28      220     43
# 9   ACRESMA01           Mark Acres         Acres    N   375     5982   1343
# 10  ACTONCH01        Charles Acton         Acton    N    23      195     77
# ...

# %%
data.drop(columns=['lastname','Name'])
# Out:
#           ilkid            firstname leag    gp  minutes    pts  oreb  dreb  \
# 0     ABDELAL01       Alaa Abdelnaby    N   256     3200   1465   283   563
# 1     ABDULKA01  Kareem Abdul-jabbar    N  1560    57446  38387  2975  9394
# 2     ABDULMA01     Mahmo Abdul-rauf    N   586    15633   8553   219   868
# 3     ABDULTA01    Tariq Abdul-wahad    N   236     4808   1830   275   501
# 4     ABDURSH01  Shareef Abdur-rahim    N   672    24862  13338  1498  3976
# ...         ...                  ...  ...   ...      ...    ...   ...   ...
# 3754  ZEVENPH01     Phil Zevenbergen    N     8       58     30     4     9
# 3755  ZIDEKGE01         George Zidek    N   135     1328    453   108   178
# 3756   ZOETJI01             Jim Zoet    N     7       30      2     3     5
# 3757   ZOPFBI01            Bill Zopf    N    53      398    118     0     0
# 3758  ZUNICMA01           Matt Zunic    N    56        0    273     0     0
#
# ...

# %%
data.head(50)
# Out:
#         ilkid            firstname      lastname leag    gp  minutes    pts  \
# 0   ABDELAL01       Alaa Abdelnaby     Abdelnaby    N   256     3200   1465
# 1   ABDULKA01  Kareem Abdul-jabbar  Abdul-jabbar    N  1560    57446  38387
# 2   ABDULMA01     Mahmo Abdul-rauf    Abdul-rauf    N   586    15633   8553
# 3   ABDULTA01    Tariq Abdul-wahad   Abdul-wahad    N   236     4808   1830
# 4   ABDURSH01  Shareef Abdur-rahim   Abdur-rahim    N   672    24862  13338
# 5   ABERNTO01        Tom Abernethy     Abernethy    N   319     5434   1779
# 6    ABLEFO01          Forest Able          Able    N     1        1      0
# 7   ABRAMJO01       John Abramovic     Abramovic    N    56        0    533
# 8   ACKERDO01      Donald Ackerman      Ackerman    N    28      220     43
# 9   ACRESMA01           Mark Acres         Acres    N   375     5982   1343
# 10  ACTONCH01        Charles Acton         Acton    N    23      195     77
# ...

# %%
data['PIR'] = PIR

# %%
data.head(50)
# Out:
#         ilkid            firstname      lastname leag    gp  minutes    pts  \
# 0   ABDELAL01       Alaa Abdelnaby     Abdelnaby    N   256     3200   1465
# 1   ABDULKA01  Kareem Abdul-jabbar  Abdul-jabbar    N  1560    57446  38387
# 2   ABDULMA01     Mahmo Abdul-rauf    Abdul-rauf    N   586    15633   8553
# 3   ABDULTA01    Tariq Abdul-wahad   Abdul-wahad    N   236     4808   1830
# 4   ABDURSH01  Shareef Abdur-rahim   Abdur-rahim    N   672    24862  13338
# 5   ABERNTO01        Tom Abernethy     Abernethy    N   319     5434   1779
# 6    ABLEFO01          Forest Able          Able    N     1        1      0
# 7   ABRAMJO01       John Abramovic     Abramovic    N    56        0    533
# 8   ACKERDO01      Donald Ackerman      Ackerman    N    28      220     43
# 9   ACRESMA01           Mark Acres         Acres    N   375     5982   1343
# 10  ACTONCH01        Charles Acton         Acton    N    23      195     77
# ...

# %%
data2 = data['firstname'].map(str)

# %%
df2 = pd.DataFrame(data2)

# %%
df2.head(50)
# Out:
#               firstname
# 0        Alaa Abdelnaby
# 1   Kareem Abdul-jabbar
# 2      Mahmo Abdul-rauf
# 3     Tariq Abdul-wahad
# 4   Shareef Abdur-rahim
# 5         Tom Abernethy
# 6           Forest Able
# 7        John Abramovic
# 8       Donald Ackerman
# 9            Mark Acres
# 10        Charles Acton
# 11          Alvan Adams
# 12            Don Adams
# 13         George Adams
# 14        Michael Adams
# 15       Rafael Addison
# 16         Rick Adelman
# 17         Mark Aguirre
# 18          Danny Ainge
# 19           Matt Aitch
# 20           Henry Akin
# 21           Henry Akin
# 22          Mark Alarie
# 23          Gary Alcorn
# 24      Chuck Aleksinas
# 25       Cory Alexander
# 26   Courtney Alexander
# 27       Gary Alexander
# 28     Victor Alexander
# 29         Steve Alford
# 30           Bill Allen
# 31            Bob Allen
# 32         Jerome Allen
# 33         Lucius Allen
# 34          Malik Allen
# 35          Randy Allen
# 36            Ray Allen
# ...

# %%
df2.rename(columns = {0:'Name'}, inplace = True)

# %%
df2.head(50)
# Out:
#               firstname
# 0        Alaa Abdelnaby
# 1   Kareem Abdul-jabbar
# 2      Mahmo Abdul-rauf
# 3     Tariq Abdul-wahad
# 4   Shareef Abdur-rahim
# 5         Tom Abernethy
# 6           Forest Able
# 7        John Abramovic
# 8       Donald Ackerman
# 9            Mark Acres
# 10        Charles Acton
# 11          Alvan Adams
# 12            Don Adams
# 13         George Adams
# 14        Michael Adams
# 15       Rafael Addison
# 16         Rick Adelman
# 17         Mark Aguirre
# 18          Danny Ainge
# 19           Matt Aitch
# 20           Henry Akin
# 21           Henry Akin
# 22          Mark Alarie
# 23          Gary Alcorn
# 24      Chuck Aleksinas
# 25       Cory Alexander
# 26   Courtney Alexander
# 27       Gary Alexander
# 28     Victor Alexander
# 29         Steve Alford
# 30           Bill Allen
# 31            Bob Allen
# 32         Jerome Allen
# 33         Lucius Allen
# 34          Malik Allen
# 35          Randy Allen
# 36            Ray Allen
# ...

# %%
df2['PIR'] =PIR

# %%
df2.head(50)
# Out:
#               firstname    PIR
# 0        Alaa Abdelnaby   1498
# 1   Kareem Abdul-jabbar  43510
# 2      Mahmo Abdul-rauf   6989
# 3     Tariq Abdul-wahad   1650
# 4   Shareef Abdur-rahim  11652
# 5         Tom Abernethy   2318
# 6           Forest Able      1
# 7        John Abramovic     31
# 8       Donald Ackerman     62
# 9            Mark Acres   2385
# 10        Charles Acton    115
# 11          Alvan Adams  16629
# 12            Don Adams   6480
# 13         George Adams   1621
# 14        Michael Adams  10208
# 15       Rafael Addison   2196
# 16         Rick Adelman   5018
# 17         Mark Aguirre  15365
# 18          Danny Ainge  13540
# 19           Matt Aitch    290
# 20           Henry Akin      1
# 21           Henry Akin    390
# 22          Mark Alarie   2636
# 23          Gary Alcorn    498
# 24      Chuck Aleksinas    433
# 25       Cory Alexander   1929
# 26   Courtney Alexander   1334
# 27       Gary Alexander     21
# 28     Victor Alexander   2673
# ...

# %%
df2.to_csv('PlayerPIR2.csv', index=False)
